# %%
import pandas as pd
import numpy as np
import statistics
from sklearn.preprocessing import MinMaxScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
aluguel_estimado_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/ALUGUEL_ESTIMADO.csv', delimiter=',')

# %%
aluguel_estimado_pof.head(15)
# Out:
#     UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  QUADRO  \
# 0   11         1103                  1  110005400        1       1       0
# 1   11         1103                  1  110005400        4       1       0
# 2   11         1103                  1  110005400        5       1       0
# 3   11         1103                  1  110005400        6       1       0
# 4   11         1103                  1  110005400        7       1       0
# 5   11         1103                  1  110005400        8       1       0
# 6   11         1103                  1  110005400        9       1       0
# 7   11         1103                  1  110005400       10       1       0
# 8   11         1103                  1  110005400       12       1       0
# 9   11         1103                  1  110005400       13       1       0
# 10  11         1109                  2  110020039        1       1       0
# ...

# %%
aluguel_estimado_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'QUADRO', 'V9001', 'V9002', 'V8000', 'V9010', 'V9011',
#        'DEFLATOR', 'V8000_DEFLA', 'COD_IMPUT_VALOR', 'FATOR_ANUALIZACAO',
#        'PESO', 'PESO_FINAL', 'RENDA_TOTAL'],
#       dtype='object')

# %%
aluguel_estimado_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48935 entries, 0 to 48934
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UF                 48935 non-null  int64
#  1   ESTRATO_POF        48935 non-null  int64
#  2   TIPO_SITUACAO_REG  48935 non-null  int64
#  3   COD_UPA            48935 non-null  int64
#  4   NUM_DOM            48935 non-null  int64
#  5   NUM_UC             48935 non-null  int64
#  6   QUADRO             48935 non-null  int64
#  7   V9001              48935 non-null  int64
#  8   V9002              48935 non-null  int64
#  9   V8000              48935 non-null  float64
#  10  V9010              48935 non-null  int64
#  11  V9011              48935 non-null  int64
#  12  DEFLATOR           48935 non-null  float64
#  13  V8000_DEFLA        48935 non-null  float64
#  14  COD_IMPUT_VALOR    48935 non-null  int64
#  15  FATOR_ANUALIZACAO  48935 non-null  int64
# ...

# %%
aluguel_estimado_pof.isnull().sum()
# Out:
# UF                   0
# ESTRATO_POF          0
# TIPO_SITUACAO_REG    0
# COD_UPA              0
# NUM_DOM              0
# NUM_UC               0
# QUADRO               0
# V9001                0
# V9002                0
# V8000                0
# V9010                0
# V9011                0
# DEFLATOR             0
# V8000_DEFLA          0
# COD_IMPUT_VALOR      0
# FATOR_ANUALIZACAO    0
# PESO                 0
# PESO_FINAL           0
# RENDA_TOTAL          0
# dtype: int64

# %%
aluguel_estimado_pof.isna().sum()
# Out:
# UF                   0
# ESTRATO_POF          0
# TIPO_SITUACAO_REG    0
# COD_UPA              0
# NUM_DOM              0
# NUM_UC               0
# QUADRO               0
# V9001                0
# V9002                0
# V8000                0
# V9010                0
# V9011                0
# DEFLATOR             0
# V8000_DEFLA          0
# COD_IMPUT_VALOR      0
# FATOR_ANUALIZACAO    0
# PESO                 0
# PESO_FINAL           0
# RENDA_TOTAL          0
# dtype: int64

# %%
aluguel_estimado_pof_zero_counts = aluguel_estimado_pof.eq(0).sum()
print(aluguel_estimado_pof_zero_counts)
# Out:
# UF                       0
# ESTRATO_POF              0
# TIPO_SITUACAO_REG        0
# COD_UPA                  0
# NUM_DOM                  0
# NUM_UC                   0
# QUADRO               48935
# V9001                    0
# V9002                    0
# V8000                    0
# V9010                    0
# V9011                   18
# DEFLATOR                 0
# V8000_DEFLA              0
# COD_IMPUT_VALOR      46446
# FATOR_ANUALIZACAO        0
# PESO                     0
# PESO_FINAL               0
# RENDA_TOTAL              0
# dtype: int64

# %%
statistics.mean(aluguel_estimado_pof['RENDA_TOTAL'])
# Out:
# 4805.206361295596

# %%
statistics.median(aluguel_estimado_pof['RENDA_TOTAL'])
# Out:
# 2998.11

# %%
statistics.mode(aluguel_estimado_pof['RENDA_TOTAL'])
# Out:
# 2978.06

# %%
aluguel_estimado_pof = aluguel_estimado_pof.drop_duplicates()

aluguel_estimado_pof.to_parquet('aluguel_estimado_pof.parquet', index=False)

# %% [markdown]
# ## Tabela 2 - POF - Domicilio

# %%
domicilio_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/DOMICILIO.csv', delimiter=',')
domicilio_pof.head(15)
# Out:
#     UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  V0201  V0202  \
# 0   11         1103                  1  110005400        1      1      1
# 1   11         1103                  1  110005400        2      1      1
# 2   11         1103                  1  110005400        4      1      4
# 3   11         1103                  1  110005400        5      1      4
# 4   11         1103                  1  110005400        6      1      1
# 5   11         1103                  1  110005400        7      1      4
# 6   11         1103                  1  110005400        8      1      1
# 7   11         1103                  1  110005400        9      1      4
# 8   11         1103                  1  110005400       10      1      1
# 9   11         1103                  1  110005400       11      1      1
# 10  11         1103                  1  110005400       12      1      1
# 11  11         1103                  1  110005400       13      1      2
# ...

# %%
domicilio_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM', 'V0201',
#        'V0202', 'V0203', 'V0204', 'V0205', 'V0206', 'V0207', 'V0208', 'V0209',
#        'V02101', 'V02102', 'V02103', 'V02104', 'V02105', 'V02111', 'V02112',
#        'V02113', 'V0212', 'V0213', 'V02141', 'V02142', 'V0215', 'V02161',
#        'V02162', 'V02163', 'V02164', 'V0217', 'V0219', 'V0220', 'V0221',
#        'PESO', 'PESO_FINAL', 'V6199'],
#       dtype='object')

# %%
domicilio_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57920 entries, 0 to 57919
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UF                 57920 non-null  int64
#  1   ESTRATO_POF        57920 non-null  int64
#  2   TIPO_SITUACAO_REG  57920 non-null  int64
#  3   COD_UPA            57920 non-null  int64
#  4   NUM_DOM            57920 non-null  int64
#  5   V0201              57920 non-null  int64
#  6   V0202              57920 non-null  int64
#  7   V0203              57920 non-null  int64
#  8   V0204              57920 non-null  int64
#  9   V0205              57920 non-null  int64
#  10  V0206              57920 non-null  int64
#  11  V0207              57920 non-null  int64
#  12  V0208              44187 non-null  float64
#  13  V0209              57920 non-null  int64
#  14  V02101             54854 non-null  float64
#  15  V02102             54854 non-null  float64
# ...

# %%
domicilio_pof.isnull().sum()
# Out:
# UF                       0
# ESTRATO_POF              0
# TIPO_SITUACAO_REG        0
# COD_UPA                  0
# NUM_DOM                  0
# V0201                    0
# V0202                    0
# V0203                    0
# V0204                    0
# V0205                    0
# V0206                    0
# V0207                    0
# V0208                13733
# V0209                    0
# V02101                3066
# V02102                3066
# V02103                3066
# V02104                3066
# V02105                3066
# V02111                   0
# V02112               55657
# V02113               56010
# V0212                  664
# V0213                    0
# V02141                   0
# V02142                   0
# V0215                  587
# V02161                   0
# V02162                   0
# V02163                   0
# V02164                   0
# V0217                    0
# V0219                48935
# V0220                    0
# ...

# %%
domicilio_pof.nunique()
# Out:
# UF                     27
# ESTRATO_POF           575
# TIPO_SITUACAO_REG       2
# COD_UPA              5501
# NUM_DOM                20
# V0201                   3
# V0202                   6
# V0203                   6
# V0204                   5
# V0205                  26
# V0206                   9
# V0207                   6
# V0208                   4
# V0209                   3
# V02101                  2
# V02102                  2
# V02103                  2
# V02104                  2
# V02105                  2
# V02111                 11
# V02112                  4
# V02113                  2
# V0212                   5
# V0213                   6
# V02141                  2
# V02142                  2
# V0215                   3
# V02161                  2
# V02162                  2
# V02163                  2
# V02164                  2
# V0217                   7
# V0219                   3
# V0220                   2
# V0221                   5
# ...

# %%
domicilio_pof_zero_counts = domicilio_pof.eq(0).sum()
print(domicilio_pof_zero_counts)
# Out:
# UF                      0
# ESTRATO_POF             0
# TIPO_SITUACAO_REG       0
# COD_UPA                 0
# NUM_DOM                 0
# V0201                   0
# V0202                   0
# V0203                   0
# V0204                   0
# V0205                   0
# V0206                   0
# V0207                   0
# V0208                   0
# V0209                   0
# V02101                  0
# V02102                  0
# V02103                  0
# V02104                  0
# V02105                  0
# V02111               2263
# V02112               1910
# V02113                  0
# V0212                   0
# V0213                   0
# V02141                  0
# V02142                  0
# V0215                   0
# V02161                  0
# V02162                  0
# V02163                  0
# V02164                  0
# V0217                   0
# V0219                   0
# V0220                   0
# V0221                   0
# ...

# %% [markdown]
# ## Tabela 3 - POF - SERVICO_NAO_MONETARIO_POF

# %%
servico_nao_monetario_pof1 = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/servico_nao_monetario_pof4.csv', delimiter=',')

# %%
servico_nao_monetario_pof1.head(15)
# Out:
#     UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  \
# 0   11         1103                  1  110005400        1       1
# 1   11         1103                  1  110005400        2       1
# 2   11         1103                  1  110005400        4       1
# 3   11         1103                  1  110005400        4       1
# 4   11         1103                  1  110005400        5       1
# 5   11         1103                  1  110005400        6       1
# 6   11         1103                  1  110005400        7       1
# 7   11         1103                  1  110005400        8       1
# 8   11         1103                  1  110005400        9       1
# 9   11         1103                  1  110005400       10       1
# 10  11         1103                  1  110005400       10       1
# 11  11         1103                  1  110005400       11       1
# 12  11         1103                  1  110005400       12       1
# ...

# %%
servico_nao_monetario_pof1.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'COD_INFORMANTE', 'QUADRO', 'SEQ', 'V9001', 'V9002', 'V8000',
#        'V9010', 'V9011', 'V4104', 'V4105', 'DEFLATOR', 'V8000_DEFLA',
#        'COD_IMPUT_VALOR', 'FATOR_ANUALIZACAO', 'PESO', 'PESO_FINAL',
#        'RENDA_TOTAL', 'V9004'],
#       dtype='object')

# %%
servico_nao_monetario_pof1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126409 entries, 0 to 126408
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   UF                 126409 non-null  int64
#  1   ESTRATO_POF        126409 non-null  int64
#  2   TIPO_SITUACAO_REG  126409 non-null  int64
#  3   COD_UPA            126409 non-null  int64
#  4   NUM_DOM            126409 non-null  int64
#  5   NUM_UC             126409 non-null  int64
#  6   COD_INFORMANTE     126409 non-null  int64
#  7   QUADRO             126409 non-null  int64
#  8   SEQ                126409 non-null  int64
#  9   V9001              126409 non-null  int64
#  10  V9002              126409 non-null  int64
#  11  V8000              126409 non-null  float64
#  12  V9010              41041 non-null   float64
#  13  V9011              41041 non-null   float64
#  14  V4104              6608 non-null    float64
# ...

# %%
servico_nao_monetario_pof1.isnull().sum()
# Out:
# UF                        0
# ESTRATO_POF               0
# TIPO_SITUACAO_REG         0
# COD_UPA                   0
# NUM_DOM                   0
# NUM_UC                    0
# COD_INFORMANTE            0
# QUADRO                    0
# SEQ                       0
# V9001                     0
# V9002                     0
# V8000                     0
# V9010                 85368
# V9011                 85368
# V4104                119801
# V4105                119801
# DEFLATOR              12854
# V8000_DEFLA               0
# COD_IMPUT_VALOR           0
# FATOR_ANUALIZACAO         0
# PESO                      0
# PESO_FINAL                0
# RENDA_TOTAL               0
# V9004                 34572
# dtype: int64

# %%
servico_nao_monetario_pof1.nunique()
# Out:
# UF                      27
# ESTRATO_POF            575
# TIPO_SITUACAO_REG        2
# COD_UPA               5357
# NUM_DOM                 20
# NUM_UC                   3
# COD_INFORMANTE          13
# QUADRO                  22
# SEQ                     54
# V9001                  581
# V9002                    5
# V8000                 1365
# V9010                   12
# V9011                   12
# V4104                    8
# V4105                    3
# DEFLATOR             23167
# V8000_DEFLA          27739
# COD_IMPUT_VALOR          2
# FATOR_ANUALIZACAO        4
# PESO                  5357
# PESO_FINAL            5357
# RENDA_TOTAL          37287
# V9004                  263
# dtype: int64

# %%
servico_nao_monetario_pof1_zero_counts = servico_nao_monetario_pof1.eq(0).sum()
print(servico_nao_monetario_pof1_zero_counts)
# Out:
# UF                       0
# ESTRATO_POF              0
# TIPO_SITUACAO_REG        0
# COD_UPA                  0
# NUM_DOM                  0
# NUM_UC                   0
# COD_INFORMANTE           0
# QUADRO                   0
# SEQ                  12654
# V9001                    0
# V9002                    0
# V8000                    0
# V9010                    0
# V9011                    0
# V4104                    0
# V4105                    0
# DEFLATOR                 0
# V8000_DEFLA              0
# COD_IMPUT_VALOR      96708
# FATOR_ANUALIZACAO        0
# PESO                     0
# PESO_FINAL               0
# RENDA_TOTAL              1
# V9004                    0
# dtype: int64

# %%
statistics.mean(servico_nao_monetario_pof1['RENDA_TOTAL'])
# Out:
# 4671.853452839592

# %%
statistics.median(servico_nao_monetario_pof1['RENDA_TOTAL'])
# Out:
# 3193.84

# %%
statistics.mode(servico_nao_monetario_pof1['RENDA_TOTAL'])
# Out:
# 2361.95

# %% [markdown]
# ## Tabela 4 - POF - SERVICO_NAO_MONETARIO_POF2

# %%
servico_nao_monetario_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/SERVICO_NAO_MONETARIO_POF2.csv', delimiter=',')

# %%
servico_nao_monetario_pof.head(15)
# Out:
#     UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  QUADRO  \
# 0   11         1105                  1  110000620        4       1       8
# 1   11         1105                  1  110000620        4       1      10
# 2   11         1105                  1  110000620        4       1      13
# 3   11         1105                  1  110000620        7       1      12
# 4   11         1105                  1  110000620       10       1       6
# 5   11         1105                  1  110000620       11       1       6
# 6   11         1103                  1  110002334        2       1      10
# 7   11         1103                  1  110005695        1       1      19
# 8   11         1103                  1  110002291       10       1       6
# 9   11         1103                  1  110010188       11       1      13
# 10  11         1105                  1  110012387       10       1       8
# ...

# %%
servico_nao_monetario_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'QUADRO', 'SEQ', 'V9001', 'V9002', 'V8000', 'V9010', 'V9011',
#        'V1904', 'V1905', 'DEFLATOR', 'V8000_DEFLA', 'V1904_DEFLA',
#        'COD_IMPUT_VALOR', 'FATOR_ANUALIZACAO', 'PESO', 'PESO_FINAL',
#        'RENDA_TOTAL', 'V9004'],
#       dtype='object')

# %%
servico_nao_monetario_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14711 entries, 0 to 14710
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UF                 14711 non-null  int64
#  1   ESTRATO_POF        14711 non-null  int64
#  2   TIPO_SITUACAO_REG  14711 non-null  int64
#  3   COD_UPA            14711 non-null  int64
#  4   NUM_DOM            14711 non-null  int64
#  5   NUM_UC             14711 non-null  int64
#  6   QUADRO             14711 non-null  int64
#  7   SEQ                14711 non-null  int64
#  8   V9001              14711 non-null  int64
#  9   V9002              14711 non-null  int64
#  10  V8000              14711 non-null  float64
#  11  V9010              2512 non-null   float64
#  12  V9011              2512 non-null   float64
#  13  V1904              68 non-null     float64
#  14  V1905              325 non-null    float64
#  15  DEFLATOR           14500 non-null  float64
# ...

# %%
servico_nao_monetario_pof.isnull().sum()
# Out:
# UF                       0
# ESTRATO_POF              0
# TIPO_SITUACAO_REG        0
# COD_UPA                  0
# NUM_DOM                  0
# NUM_UC                   0
# QUADRO                   0
# SEQ                      0
# V9001                    0
# V9002                    0
# V8000                    0
# V9010                12199
# V9011                12199
# V1904                14643
# V1905                14386
# DEFLATOR               211
# V8000_DEFLA              0
# V1904_DEFLA          14647
# COD_IMPUT_VALOR          0
# FATOR_ANUALIZACAO        0
# PESO                     0
# PESO_FINAL               0
# RENDA_TOTAL              0
# V9004                13251
# dtype: int64

# %%
servico_nao_monetario_pof.nunique()
# Out:
# UF                      27
# ESTRATO_POF            569
# TIPO_SITUACAO_REG        2
# COD_UPA               3686
# NUM_DOM                 20
# NUM_UC                   3
# QUADRO                   8
# SEQ                     31
# V9001                  114
# V9002                    5
# V8000                  860
# V9010                   12
# V9011                   12
# V1904                   14
# V1905                    3
# DEFLATOR              3503
# V8000_DEFLA           5820
# V1904_DEFLA             52
# COD_IMPUT_VALOR          2
# FATOR_ANUALIZACAO        3
# PESO                  3686
# PESO_FINAL            3686
# RENDA_TOTAL          10662
# V9004                   61
# dtype: int64

# %%
servico_nao_monetario_pof_zero_counts = servico_nao_monetario_pof.eq(0).sum()
print(servico_nao_monetario_pof_zero_counts)
# Out:
# UF                      0
# ESTRATO_POF             0
# TIPO_SITUACAO_REG       0
# COD_UPA                 0
# NUM_DOM                 0
# NUM_UC                  0
# QUADRO                  0
# SEQ                  3155
# V9001                   0
# V9002                   0
# V8000                   0
# V9010                   0
# V9011                   0
# V1904                   0
# V1905                   0
# DEFLATOR                0
# V8000_DEFLA             0
# V1904_DEFLA             0
# COD_IMPUT_VALOR      8929
# FATOR_ANUALIZACAO       0
# PESO                    0
# PESO_FINAL              0
# RENDA_TOTAL             0
# V9004                   0
# dtype: int64

# %%
statistics.mean(servico_nao_monetario_pof['RENDA_TOTAL'])
# Out:
# 3635.863125552308

# %%
statistics.median(servico_nao_monetario_pof['RENDA_TOTAL'])
# Out:
# 2595.56

# %%
statistics.mode(servico_nao_monetario_pof['RENDA_TOTAL'])
# Out:
# 10231.84

# %% [markdown]
# ## Tabela 5 - POF - Outros rendimentos

# %%
outros_rendimentos = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/outros_rendimentos.csv', delimiter=',')

# %%
outros_rendimentos.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'COD_INFORMANTE', 'QUADRO', 'SEQ', 'V9001', 'V8500', 'V8501',
#        'V9010', 'V9011', 'DEFLATOR', 'V8500_DEFLA', 'V8501_DEFLA',
#        'COD_IMPUT_VALOR', 'FATOR_ANUALIZACAO', 'PESO', 'PESO_FINAL',
#        'RENDA_TOTAL'],
#       dtype='object')

# %%
outros_rendimentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206108 entries, 0 to 206107
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   UF                 206108 non-null  int64
#  1   ESTRATO_POF        206108 non-null  int64
#  2   TIPO_SITUACAO_REG  206108 non-null  int64
#  3   COD_UPA            206108 non-null  int64
#  4   NUM_DOM            206108 non-null  int64
#  5   NUM_UC             206108 non-null  int64
#  6   COD_INFORMANTE     206108 non-null  int64
#  7   QUADRO             206108 non-null  int64
#  8   SEQ                206108 non-null  int64
#  9   V9001              206108 non-null  int64
#  10  V8500              206108 non-null  float64
#  11  V8501              65591 non-null   float64
#  12  V9010              65043 non-null   float64
#  13  V9011              65043 non-null   float64
#  14  DEFLATOR           193013 non-null  float64
# ...

# %%
outros_rendimentos.isnull().sum()
# Out:
# UF                        0
# ESTRATO_POF               0
# TIPO_SITUACAO_REG         0
# COD_UPA                   0
# NUM_DOM                   0
# NUM_UC                    0
# COD_INFORMANTE            0
# QUADRO                    0
# SEQ                       0
# V9001                     0
# V8500                     0
# V8501                140517
# V9010                141065
# V9011                141065
# DEFLATOR              13095
# V8500_DEFLA               0
# V8501_DEFLA          175447
# COD_IMPUT_VALOR           0
# FATOR_ANUALIZACAO         0
# PESO                      0
# PESO_FINAL                0
# RENDA_TOTAL               0
# dtype: int64

# %%
outros_rendimentos.nunique()
# Out:
# UF                      27
# ESTRATO_POF            575
# TIPO_SITUACAO_REG        2
# COD_UPA               5501
# NUM_DOM                 20
# NUM_UC                   3
# COD_INFORMANTE          13
# QUADRO                   4
# SEQ                     36
# V9001                  157
# V8500                15580
# V8501                 6688
# V9010                   12
# V9011                   12
# DEFLATOR               366
# V8500_DEFLA          54508
# V8501_DEFLA          14617
# COD_IMPUT_VALOR          2
# FATOR_ANUALIZACAO        1
# PESO                  5501
# PESO_FINAL            5501
# RENDA_TOTAL          50356
# dtype: int64

# %%
outros_rendimentos_zero_counts = outros_rendimentos.eq(0).sum()
print(outros_rendimentos_zero_counts)
# Out:
# UF                        0
# ESTRATO_POF               0
# TIPO_SITUACAO_REG         0
# COD_UPA                   0
# NUM_DOM                   0
# NUM_UC                    0
# COD_INFORMANTE            0
# QUADRO                    0
# SEQ                   53561
# V9001                     0
# V8500                     0
# V8501                     0
# V9010                     0
# V9011                     0
# DEFLATOR                  0
# V8500_DEFLA               0
# V8501_DEFLA               0
# COD_IMPUT_VALOR      197874
# FATOR_ANUALIZACAO         0
# PESO                      0
# PESO_FINAL                0
# RENDA_TOTAL               0
# dtype: int64

# %%
statistics.mean(outros_rendimentos['RENDA_TOTAL'])
# Out:
# 6561.741957711491

# %%
statistics.median(outros_rendimentos['RENDA_TOTAL'])
# Out:
# 4136.71

# %%
statistics.mode(outros_rendimentos['RENDA_TOTAL'])
# Out:
# 16935.91

# %% [markdown]
# ## Tabela 6 - POF - Morador

# %%
morador_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/MORADOR.csv', delimiter=',')

# %%
morador_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'COD_INFORMANTE', 'V0306', 'V0401', 'V04021', 'V04022',
#        'V04023', 'V0403', 'V0404', 'V0405', 'V0406', 'V0407', 'V0408', 'V0409',
#        'V0410', 'V0411', 'V0412', 'V0413', 'V0414', 'V0415', 'V0416',
#        'V041711', 'V041712', 'V041721', 'V041722', 'V041731', 'V041732',
#        'V041741', 'V041742', 'V0418', 'V0419', 'V0420', 'V0421', 'V0422',
#        'V0423', 'V0424', 'V0425', 'V0426', 'V0427', 'V0428', 'V0429', 'V0430',
#        'ANOS_ESTUDO', 'PESO', 'PESO_FINAL', 'RENDA_TOTAL', 'NIVEL_INSTRUCAO',
#        'RENDA_DISP_PC', 'RENDA_MONET_PC', 'RENDA_NAO_MONET_PC', 'DEDUCAO_PC'],
#       dtype='object')

# %%
morador_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178431 entries, 0 to 178430
# Data columns (total 56 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   UF                  178431 non-null  int64
#  1   ESTRATO_POF         178431 non-null  int64
#  2   TIPO_SITUACAO_REG   178431 non-null  int64
#  3   COD_UPA             178431 non-null  int64
#  4   NUM_DOM             178431 non-null  int64
#  5   NUM_UC              178431 non-null  int64
#  6   COD_INFORMANTE      178431 non-null  int64
#  7   V0306               178431 non-null  int64
#  8   V0401               178431 non-null  int64
#  9   V04021              178431 non-null  int64
#  10  V04022              178431 non-null  int64
#  11  V04023              178431 non-null  int64
#  12  V0403               178431 non-null  int64
#  13  V0404               178431 non-null  int64
#  14  V0405               178431 non-null  int64
# ...

# %%
morador_pof.isnull().sum()
# Out:
# UF                         0
# ESTRATO_POF                0
# TIPO_SITUACAO_REG          0
# COD_UPA                    0
# NUM_DOM                    0
# NUM_UC                     0
# COD_INFORMANTE             0
# V0306                      0
# V0401                      0
# V04021                     0
# V04022                     0
# V04023                     0
# V0403                      0
# V0404                      0
# V0405                      0
# V0406                      0
# V0407                  30315
# V0408                  30315
# V0409                  50153
# V0410                  50153
# V0411                 125790
# V0412                 166095
# V0413                  50153
# V0414                      0
# V0415                      0
# V0416                 161701
# V041711               161701
# V041712               175393
# V041721               161701
# V041722               164200
# V041731               161701
# V041732               175055
# ...

# %%
morador_pof.nunique()
# Out:
# UF                       27
# ESTRATO_POF             575
# TIPO_SITUACAO_REG         2
# COD_UPA                5501
# NUM_DOM                  20
# NUM_UC                    3
# COD_INFORMANTE           17
# V0306                    19
# V0401                     2
# V04021                   32
# V04022                   13
# V04023                  110
# V0403                   110
# V0404                     2
# V0405                     6
# V0406                     2
# V0407                     2
# V0408                     2
# V0409                    14
# V0410                     7
# V0411                     8
# V0412                     2
# V0413                     7
# V0414                     2
# V0415                     2
# V0416                     6
# V041711                   2
# V041712                   2
# V041721                   2
# V041722                   2
# V041731                   2
# V041732                   2
# V041741                   2
# ...

# %%
morador_pof_zero_counts = morador_pof.eq(0).sum()
print(morador_pof_zero_counts)
# Out:
# UF                        0
# ESTRATO_POF               0
# TIPO_SITUACAO_REG         0
# COD_UPA                   0
# NUM_DOM                   0
# NUM_UC                    0
# COD_INFORMANTE            0
# V0306                     0
# V0401                     0
# V04021                    0
# V04022                    0
# V04023                    0
# V0403                  2121
# V0404                     0
# V0405                     0
# V0406                     0
# V0407                     0
# V0408                     0
# V0409                 92702
# V0410                 75637
# V0411                 40305
# V0412                     0
# V0413                 82860
# V0414                     0
# V0415                     0
# V0416                     0
# V041711                   0
# V041712                   0
# V041721                   0
# V041722                   0
# V041731                   0
# V041732                   0
# V041741                   0
# ...

# %%
statistics.mean(morador_pof['RENDA_TOTAL'])
# Out:
# 4864.562583687813

# %%
statistics.median(morador_pof['RENDA_TOTAL'])
# Out:
# 3129.63

# %%
statistics.mode(morador_pof['RENDA_TOTAL'])
# Out:
# 0.0

# %% [markdown]
# ## Tabela 7 - Morador Qualidade de Vida - POF

# %%
morador_por_qualidade_vida = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/MORADOR_QUALI_VIDA.csv', delimiter=',')

# %%
morador_por_qualidade_vida.head(5)
# Out:
#    UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  \
# 0  11         1103                  1  110005400        1       1
# 1  11         1103                  1  110005400        1       1
# 2  11         1103                  1  110005400        1       1
# 3  11         1103                  1  110005400        1       1
# 4  11         1103                  1  110005400        2       1
#
#    COD_INFORMANTE  CONTAGEM_PONDERADA  FUNCAO_PERDA  V201  ...  C2  C3  C4  \
# 0               1            0.177778      0.113229     0  ...   1   2   7
# 1               2            0.177778      0.113229     0  ...   1   2   7
# 2               3            0.177778      0.113229     0  ...   1   2   7
# 3               4            0.177778      0.113229     0  ...   1   2   7
# 4               1            0.300000      0.203610     0  ...   1   2   5
#
#    C5  C6  C7  RENDA_DISP_PC  RENDA_DISP_PC_SS        PESO  PESO_FINAL
# ...

# %%
morador_por_qualidade_vida.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'COD_INFORMANTE', 'CONTAGEM_PONDERADA', 'FUNCAO_PERDA',
#        'V201', 'V202', 'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V210',
#        'V211', 'V212', 'V214', 'V215', 'V216', 'V217', 'V301', 'V302', 'V303',
#        'V304', 'V305', 'V306', 'V307', 'V308', 'V401', 'V402', 'V403', 'V501',
#        'V502', 'V503', 'V504', 'V505', 'V506', 'V601', 'V602', 'V603', 'V604',
#        'V605', 'V606', 'V607', 'V608', 'V609', 'V610', 'V611', 'V701', 'V702',
#        'V703', 'V704', 'V801', 'V802', 'V901', 'V902', 'GRANDE_REGIAO', 'C1',
#        'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'RENDA_DISP_PC', 'RENDA_DISP_PC_SS',
#        'PESO', 'PESO_FINAL'],
#       dtype='object')

# %%
morador_por_qualidade_vida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178369 entries, 0 to 178368
# Data columns (total 72 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   UF                  178369 non-null  int64
#  1   ESTRATO_POF         178369 non-null  int64
#  2   TIPO_SITUACAO_REG   178369 non-null  int64
#  3   COD_UPA             178369 non-null  int64
#  4   NUM_DOM             178369 non-null  int64
#  5   NUM_UC              178369 non-null  int64
#  6   COD_INFORMANTE      178369 non-null  int64
#  7   CONTAGEM_PONDERADA  178369 non-null  float64
#  8   FUNCAO_PERDA        178369 non-null  float64
#  9   V201                178369 non-null  int64
#  10  V202                178369 non-null  int64
#  11  V204                178369 non-null  int64
#  12  V205                178369 non-null  int64
#  13  V206                178369 non-null  int64
#  14  V207                178369 non-null  int64
# ...

# %%
morador_por_qualidade_vida.isnull().sum()
# Out:
# UF                   0
# ESTRATO_POF          0
# TIPO_SITUACAO_REG    0
# COD_UPA              0
# NUM_DOM              0
#                     ..
# C7                   0
# RENDA_DISP_PC        0
# RENDA_DISP_PC_SS     0
# PESO                 0
# PESO_FINAL           0
# Length: 72, dtype: int64

# %%
morador_por_qualidade_vida.nunique()
# Out:
# UF                      27
# ESTRATO_POF            575
# TIPO_SITUACAO_REG        2
# COD_UPA               5501
# NUM_DOM                 20
#                      ...
# C7                      10
# RENDA_DISP_PC        57941
# RENDA_DISP_PC_SS     57916
# PESO                  5501
# PESO_FINAL            5501
# Length: 72, dtype: int64

# %%
morador_por_qualidade_vida_zero_counts = morador_por_qualidade_vida.eq(0).sum()
print(morador_por_qualidade_vida_zero_counts)
# Out:
# UF                    0
# ESTRATO_POF           0
# TIPO_SITUACAO_REG     0
# COD_UPA               0
# NUM_DOM               0
#                      ..
# C7                    0
# RENDA_DISP_PC        23
# RENDA_DISP_PC_SS     28
# PESO                  0
# PESO_FINAL            0
# Length: 72, dtype: int64

# %% [markdown]
# ## Tabela 8 - Caderneta Coletiva - POF

# %%
caderneta_coletiva_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/caderneta_coletiva.csv')
caderneta_coletiva_pof.head(5)
# Out:
#    UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  QUADRO  \
# 0  11         1103                  1  110005400        1       1      67
# 1  11         1103                  1  110005400        1       1      67
# 2  11         1103                  1  110005400        1       1      67
# 3  11         1103                  1  110005400        1       1      67
# 4  11         1103                  1  110005400        1       1      67
#
#    SEQ    V9001  V9002  ...  COD_IMPUT_VALOR  FATOR_ANUALIZACAO        PESO  \
# 0    1  6300112      3  ...                0                 52  272.806669
# 1    2  7100201      3  ...                0                 52  272.806669
# 2    3  8300101      3  ...                0                 52  272.806669
# 3    4  6400601      3  ...                0                 52  272.806669
# 4    5  6900901      3  ...                0                 52  272.806669
#
# ...

# %%
caderneta_coletiva_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'QUADRO', 'SEQ', 'V9001', 'V9002', 'V8000', 'DEFLATOR',
#        'V8000_DEFLA', 'COD_IMPUT_VALOR', 'FATOR_ANUALIZACAO', 'PESO',
#        'PESO_FINAL', 'RENDA_TOTAL', 'V9005', 'V9007', 'V9009', 'QTD_FINAL',
#        'V9004'],
#       dtype='object')

# %%
caderneta_coletiva_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789995 entries, 0 to 789994
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   UF                 789995 non-null  int64
#  1   ESTRATO_POF        789995 non-null  int64
#  2   TIPO_SITUACAO_REG  789995 non-null  int64
#  3   COD_UPA            789995 non-null  int64
#  4   NUM_DOM            789995 non-null  int64
#  5   NUM_UC             789995 non-null  int64
#  6   QUADRO             789995 non-null  int64
#  7   SEQ                789995 non-null  int64
#  8   V9001              789995 non-null  int64
#  9   V9002              789995 non-null  int64
#  10  V8000              789995 non-null  float64
#  11  DEFLATOR           735853 non-null  float64
#  12  V8000_DEFLA        789995 non-null  float64
#  13  COD_IMPUT_VALOR    789995 non-null  int64
#  14  FATOR_ANUALIZACAO  789995 non-null  int64
# ...

# %%
caderneta_coletiva_pof.isnull().sum()
# Out:
# UF                        0
# ESTRATO_POF               0
# TIPO_SITUACAO_REG         0
# COD_UPA                   0
# NUM_DOM                   0
# NUM_UC                    0
# QUADRO                    0
# SEQ                       0
# V9001                     0
# V9002                     0
# V8000                     0
# DEFLATOR              54142
# V8000_DEFLA               0
# COD_IMPUT_VALOR           0
# FATOR_ANUALIZACAO         0
# PESO                      0
# PESO_FINAL                0
# RENDA_TOTAL               0
# V9005                 64052
# V9007                 64052
# V9009                510377
# QTD_FINAL             71434
# V9004                     0
# dtype: int64

# %%
caderneta_coletiva_pof.nunique()
# Out:
# UF                       27
# ESTRATO_POF             575
# TIPO_SITUACAO_REG         2
# COD_UPA                5495
# NUM_DOM                  20
# NUM_UC                    3
# QUADRO                    7
# SEQ                     136
# V9001                  4848
# V9002                    11
# V8000                  6564
# DEFLATOR             205676
# V8000_DEFLA            9742
# COD_IMPUT_VALOR           2
# FATOR_ANUALIZACAO         1
# PESO                   5495
# PESO_FINAL             5495
# RENDA_TOTAL           48766
# V9005                  6156
# V9007                   290
# V9009                   671
# QTD_FINAL              7566
# V9004                   372
# dtype: int64

# %%
caderneta_coletiva_pof_zero_counts = caderneta_coletiva_pof.eq(0).sum()
print(caderneta_coletiva_pof_zero_counts)
# Out:
# UF                        0
# ESTRATO_POF               0
# TIPO_SITUACAO_REG         0
# COD_UPA                   0
# NUM_DOM                   0
# NUM_UC                    0
# QUADRO                    0
# SEQ                       0
# V9001                     0
# V9002                     0
# V8000                     0
# DEFLATOR                  0
# V8000_DEFLA               0
# COD_IMPUT_VALOR      779701
# FATOR_ANUALIZACAO         0
# PESO                      0
# PESO_FINAL                0
# RENDA_TOTAL              59
# V9005                     0
# V9007                     0
# V9009                     0
# QTD_FINAL                 0
# V9004                     0
# dtype: int64

# %%
statistics.mean(caderneta_coletiva_pof['RENDA_TOTAL'])
# Out:
# 5960.231367565618

# %%
statistics.median(caderneta_coletiva_pof['RENDA_TOTAL'])
# Out:
# 3606.09

# %%
statistics.mode(caderneta_coletiva_pof['RENDA_TOTAL'])
# Out:
# 19805.35

# %% [markdown]
# ## Tabela 9 - Despesa Individual - POF

# %%
despesa_individual_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/despesa_individual.csv', delimiter=',')
despesa_individual_pof.head(5)
# Out:
#    UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  \
# 0  11         1103                  1  110005400        1       1
# 1  11         1103                  1  110005400        1       1
# 2  11         1103                  1  110005400        1       1
# 3  11         1103                  1  110005400        1       1
# 4  11         1103                  1  110005400        1       1
#
#    COD_INFORMANTE  QUADRO  SEQ    V9001  ...  V4104  V4105  DEFLATOR  \
# 0               2      22    0  2200101  ...    NaN    NaN  1.000000
# 1               1      23   13  2301401  ...    NaN    NaN  1.050646
# 2               1      24    0  2400101  ...    NaN    NaN  1.013176
# 3               2      24    0  2400101  ...    NaN    NaN  1.013176
# 4               1      24   18  2401901  ...    NaN    NaN  1.021505
#
#    V8000_DEFLA  COD_IMPUT_VALOR  FATOR_ANUALIZACAO        PESO  PESO_FINAL  \
# ...

# %%
despesa_individual_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'COD_INFORMANTE', 'QUADRO', 'SEQ', 'V9001', 'V9002', 'V8000',
#        'V9010', 'V9011', 'V9012', 'V4104', 'V4105', 'DEFLATOR', 'V8000_DEFLA',
#        'COD_IMPUT_VALOR', 'FATOR_ANUALIZACAO', 'PESO', 'PESO_FINAL',
#        'RENDA_TOTAL', 'V9004'],
#       dtype='object')

# %%
despesa_individual_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1836032 entries, 0 to 1836031
# Data columns (total 25 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   UF                 int64
#  1   ESTRATO_POF        int64
#  2   TIPO_SITUACAO_REG  int64
#  3   COD_UPA            int64
#  4   NUM_DOM            int64
#  5   NUM_UC             int64
#  6   COD_INFORMANTE     int64
#  7   QUADRO             int64
#  8   SEQ                int64
#  9   V9001              int64
#  10  V9002              int64
#  11  V8000              float64
#  12  V9010              float64
#  13  V9011              float64
#  14  V9012              float64
#  15  V4104              float64
#  16  V4105              float64
#  17  DEFLATOR           float64
#  18  V8000_DEFLA        float64
#  19  COD_IMPUT_VALOR    int64
#  20  FATOR_ANUALIZACAO  int64
#  21  PESO               float64
#  22  PESO_FINAL         float64
#  23  RENDA_TOTAL        float64
# ...

# %%
despesa_individual_pof.isnull().sum()
# Out:
# UF                         0
# ESTRATO_POF                0
# TIPO_SITUACAO_REG          0
# COD_UPA                    0
# NUM_DOM                    0
# NUM_UC                     0
# COD_INFORMANTE             0
# QUADRO                     0
# SEQ                        0
# V9001                      0
# V9002                      0
# V8000                      0
# V9010                1549582
# V9011                1549582
# V9012                1821652
# V4104                1787776
# V4105                1787776
# DEFLATOR              191540
# V8000_DEFLA                0
# COD_IMPUT_VALOR            0
# FATOR_ANUALIZACAO          0
# PESO                       0
# PESO_FINAL                 0
# RENDA_TOTAL                0
# V9004                 457242
# dtype: int64

# %%
despesa_individual_pof.nunique()
# Out:
# UF                       27
# ESTRATO_POF             575
# TIPO_SITUACAO_REG         2
# COD_UPA                5501
# NUM_DOM                  20
# NUM_UC                    3
# COD_INFORMANTE           13
# QUADRO                   31
# SEQ                      91
# V9001                  2766
# V9002                    11
# V8000                 14766
# V9010                    12
# V9011                    12
# V9012                     3
# V4104                     8
# V4105                     3
# DEFLATOR             248151
# V8000_DEFLA           96279
# COD_IMPUT_VALOR           2
# FATOR_ANUALIZACAO         4
# PESO                   5501
# PESO_FINAL             5501
# RENDA_TOTAL           55752
# V9004                   699
# dtype: int64

# %%
despesa_individual_pof_zero_counts = despesa_individual_pof.eq(0).sum()
print(despesa_individual_pof_zero_counts)
# Out:
# UF                         0
# ESTRATO_POF                0
# TIPO_SITUACAO_REG          0
# COD_UPA                    0
# NUM_DOM                    0
# NUM_UC                     0
# COD_INFORMANTE             0
# QUADRO                     0
# SEQ                   386755
# V9001                      0
# V9002                      0
# V8000                      0
# V9010                      0
# V9011                      0
# V9012                      0
# V4104                      0
# V4105                      0
# DEFLATOR                   0
# V8000_DEFLA                0
# COD_IMPUT_VALOR      1752171
# FATOR_ANUALIZACAO          0
# PESO                       0
# PESO_FINAL                 0
# RENDA_TOTAL               42
# V9004                      0
# dtype: int64

# %%
statistics.mean(despesa_individual_pof['RENDA_TOTAL'])
# Out:
# 6415.419691633915

# %%
statistics.median(despesa_individual_pof['RENDA_TOTAL'])
# Out:
# 3944.26

# %%
statistics.mode(despesa_individual_pof['RENDA_TOTAL'])
# Out:
# 16060.67

# %% [markdown]
# ## Tabela 10 - Despesa Coletiva - POF

# %%
despesa_coletiva_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/DESPESA_COLETIVA.csv', delimiter=',')
despesa_coletiva_pof.head(5)
# Out:
#    UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  QUADRO  \
# 0  11         1103                  1  110005400        1       1       6
# 1  11         1103                  1  110005400        1       1       6
# 2  11         1103                  1  110005400        1       1       6
# 3  11         1103                  1  110005400        1       1       6
# 4  11         1103                  1  110005400        1       1       6
#
#    SEQ   V9001  V9002  ...  DEFLATOR  V8000_DEFLA  V1904_DEFLA  \
# 0    0  600101      1  ...  0.892857       248.21          NaN
# 1    1  600201      1  ...  1.084304        48.79          NaN
# 2    3  600401      1  ...  0.981176       115.78          NaN
# 3    4  600501      1  ...  1.000000        80.00          NaN
# 4    5  600601      1  ...  1.000000       100.00          NaN
#
#    COD_IMPUT_VALOR  COD_IMPUT_QUANTIDADE  FATOR_ANUALIZACAO        PESO  \
# ...

# %%
despesa_coletiva_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'QUADRO', 'SEQ', 'V9001', 'V9002', 'V9005', 'V8000', 'V9010',
#        'V9011', 'V9012', 'V1904', 'V1905', 'DEFLATOR', 'V8000_DEFLA',
#        'V1904_DEFLA', 'COD_IMPUT_VALOR', 'COD_IMPUT_QUANTIDADE',
#        'FATOR_ANUALIZACAO', 'PESO', 'PESO_FINAL', 'RENDA_TOTAL', 'V9004'],
#       dtype='object')

# %%
despesa_coletiva_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478572 entries, 0 to 478571
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   UF                    478572 non-null  int64
#  1   ESTRATO_POF           478572 non-null  int64
#  2   TIPO_SITUACAO_REG     478572 non-null  int64
#  3   COD_UPA               478572 non-null  int64
#  4   NUM_DOM               478572 non-null  int64
#  5   NUM_UC                478572 non-null  int64
#  6   QUADRO                478572 non-null  int64
#  7   SEQ                   478572 non-null  int64
#  8   V9001                 478572 non-null  int64
#  9   V9002                 478572 non-null  int64
#  10  V9005                 52182 non-null   float64
#  11  V8000                 478572 non-null  float64
#  12  V9010                 44470 non-null   float64
#  13  V9011                 44470 non-null   float64
# ...

# %%
despesa_coletiva_pof.isnull().sum()
# Out:
# UF                           0
# ESTRATO_POF                  0
# TIPO_SITUACAO_REG            0
# COD_UPA                      0
# NUM_DOM                      0
# NUM_UC                       0
# QUADRO                       0
# SEQ                          0
# V9001                        0
# V9002                        0
# V9005                   426390
# V8000                        0
# V9010                   434102
# V9011                   434102
# V9012                   340149
# V1904                   477120
# V1905                   468295
# DEFLATOR                  7960
# V8000_DEFLA                  0
# V1904_DEFLA             477130
# COD_IMPUT_VALOR              0
# COD_IMPUT_QUANTIDADE    426390
# FATOR_ANUALIZACAO            0
# PESO                         0
# PESO_FINAL                   0
# RENDA_TOTAL                  0
# V9004                   219827
# dtype: int64

# %%
despesa_coletiva_pof.nunique()
# Out:
# UF                         27
# ESTRATO_POF               575
# TIPO_SITUACAO_REG           2
# COD_UPA                  5501
# NUM_DOM                    20
# NUM_UC                      3
# QUADRO                     13
# SEQ                        63
# V9001                     999
# V9002                      11
# V9005                     996
# V8000                   22576
# V9010                      12
# V9011                      12
# V9012                       3
# V1904                     285
# V1905                       3
# DEFLATOR                36620
# V8000_DEFLA             85506
# V1904_DEFLA              1051
# COD_IMPUT_VALOR             2
# COD_IMPUT_QUANTIDADE        2
# FATOR_ANUALIZACAO           3
# PESO                     5501
# PESO_FINAL               5501
# RENDA_TOTAL             55687
# V9004                     465
# dtype: int64

# %%
despesa_coletiva_pof_zero_counts = despesa_coletiva_pof.eq(0).sum()
print(despesa_coletiva_pof_zero_counts)
# Out:
# UF                           0
# ESTRATO_POF                  0
# TIPO_SITUACAO_REG            0
# COD_UPA                      0
# NUM_DOM                      0
# NUM_UC                       0
# QUADRO                       0
# SEQ                     132418
# V9001                        0
# V9002                        0
# V9005                        0
# V8000                        0
# V9010                        0
# V9011                        0
# V9012                        0
# V1904                        0
# V1905                        0
# DEFLATOR                     0
# V8000_DEFLA                  0
# V1904_DEFLA                  0
# COD_IMPUT_VALOR         453788
# COD_IMPUT_QUANTIDADE     33848
# FATOR_ANUALIZACAO            0
# PESO                         0
# PESO_FINAL                   0
# RENDA_TOTAL                 22
# V9004                        0
# dtype: int64

# %%
statistics.mean(despesa_coletiva_pof['RENDA_TOTAL'])
# Out:
# 5802.390797163227

# %%
statistics.median(despesa_coletiva_pof['RENDA_TOTAL'])
# Out:
# 3513.54

# %%
statistics.mode(despesa_coletiva_pof['RENDA_TOTAL'])
# Out:
# 3901.03

# %% [markdown]
# ## Tabela 11 - Consumo Alimentar - POF

# %%
consumo_alimentar_pof = pd.read_csv('/content/drive/Shareddrives/modulo_8/Dados_em_CSV_POF/consumo_alimentar.csv', delimiter=',')
consumo_alimentar_pof.head(5)
# Out:
#    UF  ESTRATO_POF  TIPO_SITUACAO_REG    COD_UPA  NUM_DOM  NUM_UC  \
# 0  11         1101                  1  110000016        2       1
# 1  11         1101                  1  110000016        2       1
# 2  11         1101                  1  110000016        2       1
# 3  11         1101                  1  110000016        2       1
# 4  11         1101                  1  110000016        2       1
#
#    COD_INFOR.MANTE  QUADRO  SEQ  V9005  ...  COBALAMINA  VITD    VITE   VITC  \
# 0                1      72    1    1.0  ...       0.000   0.0  0.1260  0.000
# 1                1      72    1    NaN  ...       0.000   0.0  0.7924  0.000
# 2                1      72    2    1.0  ...       0.285   0.0  0.0750  0.000
# 3                1      72    2    NaN  ...       0.000   0.0  0.0000  0.000
# 4                1      72    3    2.0  ...       0.000   0.0  0.1620  0.405
#
#      FOLATO         PESO   PESO_FINAL  RENDA_TOTAL       DIA_SEMANA  \
# ...

# %%
consumo_alimentar_pof.columns
# Out:
# Index(['UF', 'ESTRATO_POF', 'TIPO_SITUACAO_REG', 'COD_UPA', 'NUM_DOM',
#        'NUM_UC', 'COD_INFOR.MANTE', 'QUADRO', 'SEQ', 'V9005', 'V9007', 'V9001',
#        'V9015', 'V9016', 'V9017', 'V9018', 'V9019', 'V9020', 'V9021', 'V9022',
#        'V9023', 'V9024', 'V9025', 'V9026', 'V9027', 'V9028', 'V9029', 'V9030',
#        'COD_UNIDADE_MEDIDA_FINAL', 'COD_PREPARACAO_FINAL', 'GRAMATURA1', 'QTD',
#        'COD_TBCA', 'ENERGIA_KCAL', 'ENERGIA_KJ', 'PTN', 'CHOTOT', 'FIBRA',
#        'LIP', 'COLEST', 'AGSAT', 'AGMONO', 'AGPOLI', 'AGTRANS', 'CALCIO',
#        'FERRO', 'SODIO', 'MAGNESIO', 'FOSFORO', 'POTASSIO', 'COBRE', 'ZINCO',
#        'VITA_RAE', 'TIAMINA', 'RIBOFLAVINA', 'NIACINA', 'PIRIDOXAMINA',
#        'COBALAMINA', 'VITD', 'VITE', 'VITC', 'FOLATO', 'PESO', 'PESO_FINAL',
#        'RENDA_TOTAL', 'DIA_SEMANA', 'DIA_ATIPICO'],
#       dtype='object')

# %%
consumo_alimentar_pof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175390 entries, 0 to 1175389
# Data columns (total 67 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UF                        1175390 non-null  int64
#  1   ESTRATO_POF               1175390 non-null  int64
#  2   TIPO_SITUACAO_REG         1175390 non-null  int64
#  3   COD_UPA                   1175390 non-null  int64
#  4   NUM_DOM                   1175390 non-null  int64
#  5   NUM_UC                    1175390 non-null  int64
#  6   COD_INFOR.MANTE           1175390 non-null  int64
#  7   QUADRO                    1175390 non-null  int64
#  8   SEQ                       1175390 non-null  int64
#  9   V9005                     1007126 non-null  float64
#  10  V9007                     1007126 non-null  float64
#  11  V9001                     1175390 non-null  int64
#  12  V9015                     1175390 non-null  object
# ...

# %%
consumo_alimentar_pof.isnull().sum()
# Out:
# UF                   0
# ESTRATO_POF          0
# TIPO_SITUACAO_REG    0
# COD_UPA              0
# NUM_DOM              0
#                     ..
# PESO                 0
# PESO_FINAL           0
# RENDA_TOTAL          0
# DIA_SEMANA           0
# DIA_ATIPICO          0
# Length: 67, dtype: int64

# %%
consumo_alimentar_pof.nunique()
# Out:
# UF                      27
# ESTRATO_POF            575
# TIPO_SITUACAO_REG        2
# COD_UPA               5404
# NUM_DOM                 20
#                      ...
# PESO                  5403
# PESO_FINAL           19663
# RENDA_TOTAL          19867
# DIA_SEMANA               7
# DIA_ATIPICO              2
# Length: 67, dtype: int64

# %%
consumo_alimentar_pof_zero_counts = consumo_alimentar_pof.eq(0).sum()
print(consumo_alimentar_pof_zero_counts)
# Out:
# UF                    0
# ESTRATO_POF           0
# TIPO_SITUACAO_REG     0
# COD_UPA               0
# NUM_DOM               0
#                      ..
# PESO                  0
# PESO_FINAL            0
# RENDA_TOTAL          86
# DIA_SEMANA            0
# DIA_ATIPICO           0
# Length: 67, dtype: int64

# %%
statistics.mean(consumo_alimentar_pof['RENDA_TOTAL'])
# Out:
# 4967.096795157352

# %%
statistics.median(consumo_alimentar_pof['RENDA_TOTAL'])
# Out:
# 3246.33

# %%
statistics.mode(consumo_alimentar_pof['RENDA_TOTAL'])
# Out:
# 3163.55

# %%
statistics.mean(consumo_alimentar_pof['PESO'])
# Out:
# 2734.3989062004334

# %%
statistics.mode(consumo_alimentar_pof['PESO'])
# Out:
# 1890.81711538

# %%
statistics.mean(consumo_alimentar_pof['PESO_FINAL'])
# Out:
# 3832.2369992190033

# %%
statistics.mode(consumo_alimentar_pof['PESO_FINAL'])
# Out:
# 881.89845438
