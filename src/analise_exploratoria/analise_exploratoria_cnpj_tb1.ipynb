# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
tabela1_cnpj = pd.read_csv('/content/drive/MyDrive/cnpjs_1.csv', delimiter=';')
# Out:
# <ipython-input-10-fb477b51e871>:1: DtypeWarning: Columns (10,23,25,29,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela1_cnpj = pd.read_csv('/content/drive/MyDrive/cnpjs_1.csv', delimiter=';')

# %%
tabela1_cnpj.head(15)
# Out:
#           data            cnpj  cnpj_basico  cnpj_ordem  cnpj_dv  \
# 0   2023-02-15  97253082000207     97253082           2        7
# 1   2023-02-15   3151122000177      3151122           1       77
# 2   2022-09-11  27738772000181     27738772           1       81
# 3   2022-09-11  17096193000129     17096193           1       29
# 4   2022-09-11  23202167000130     23202167           1       30
# 5   2023-02-15   3468255000171      3468255           1       71
# 6   2023-02-15   4268700000112      4268700           1       12
# 7   2023-02-15  39953783000163     39953783           1       63
# 8   2023-02-15  39746302000149     39746302           1       49
# 9   2023-02-15  18556963000131     18556963           1       31
# 10  2022-09-11  46370493000152     46370493           1       52
# 11  2022-11-24  43854362000152     43854362           1       52
# 12  2021-12-24  18756711000156     18756711           1       56
# ...

# %%
tabela1_cnpj.columns
# Out:
# Index(['data', 'cnpj', 'cnpj_basico', 'cnpj_ordem', 'cnpj_dv',
#        'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral',
#        'data_situacao_cadastral', 'motivo_situacao_cadastral',
#        'nome_cidade_exterior', 'id_pais', 'data_inicio_atividade',
#        'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'sigla_uf',
#        'id_municipio', 'id_municipio_rf', 'tipo_logradouro', 'logradouro',
#        'numero', 'complemento', 'bairro', 'cep', 'ddd_1', 'telefone_1',
#        'ddd_2', 'telefone_2', 'ddd_fax', 'fax', 'email', 'situacao_especial',
#        'data_situacao_especial'],
#       dtype='object')

# %%
tabela1_cnpj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5474156 entries, 0 to 5474155
# Data columns (total 33 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   data                         object
#  1   cnpj                         int64
#  2   cnpj_basico                  int64
#  3   cnpj_ordem                   int64
#  4   cnpj_dv                      int64
#  5   identificador_matriz_filial  int64
#  6   nome_fantasia                object
#  7   situacao_cadastral           int64
#  8   data_situacao_cadastral      object
#  9   motivo_situacao_cadastral    int64
#  10  nome_cidade_exterior         object
#  11  id_pais                      float64
#  12  data_inicio_atividade        object
#  13  cnae_fiscal_principal        int64
#  14  cnae_fiscal_secundaria       object
#  15  sigla_uf                     object
#  16  id_municipio                 float64
#  17  id_municipio_rf              int64
# ...

# %%
df_counts = pd.DataFrame(tabela1_cnpj)
value_counts_per_column = df_counts.apply(lambda x: x.value_counts())

print (value_counts_per_column)
# Out:
#                   data  cnpj  cnpj_basico  cnpj_ordem   cnpj_dv  \
# 0                  NaN   NaN          NaN         NaN  182338.0
# 1                  NaN   NaN          NaN   5325160.0   92164.0
# 2                  NaN   NaN          NaN     84058.0   90082.0
# 3                  NaN   NaN          NaN     19103.0   91121.0
# 4                  NaN   NaN          NaN      8073.0   91029.0
# ...                ...   ...          ...         ...       ...
# ÁTICA              NaN   NaN          NaN         NaN       NaN
# ÂNGELO GIUBERTI    NaN   NaN          NaN         NaN       NaN
# ÂNGELO ROSENENTE   NaN   NaN          NaN         NaN       NaN
# ÂNGELO TELES       NaN   NaN          NaN         NaN       NaN
# ÂNGELO ZARDINE     NaN   NaN          NaN         NaN       NaN
#
#                   identificador_matriz_filial  nome_fantasia  \
# 0                                         NaN            NaN
# 1                                   5325551.0            NaN
# ...

# %%
tabela1_cnpj.corr()
# Out:
# <ipython-input-16-0ee8f44c0461>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tabela1_cnpj.corr()
#                                  cnpj  cnpj_basico  cnpj_ordem   cnpj_dv  \
# cnpj                         1.000000     1.000000   -0.019739 -0.001690
# cnpj_basico                  1.000000     1.000000   -0.019739 -0.001690
# cnpj_ordem                  -0.019739    -0.019739    1.000000  0.000790
# cnpj_dv                     -0.001690    -0.001690    0.000790  1.000000
# identificador_matriz_filial -0.109572    -0.109572    0.193634  0.002673
# situacao_cadastral                NaN          NaN         NaN       NaN
# motivo_situacao_cadastral         NaN          NaN         NaN       NaN
# id_pais                     -0.622313    -0.622313         NaN  0.006230
# ...

# %%
tabela1_cnpj.isnull().sum()
# Out:
# data                                 0
# cnpj                                 0
# cnpj_basico                          0
# cnpj_ordem                           0
# cnpj_dv                              0
# identificador_matriz_filial          0
# nome_fantasia                   816240
# situacao_cadastral                   0
# data_situacao_cadastral          30870
# motivo_situacao_cadastral            0
# nome_cidade_exterior           5474031
# id_pais                        5422998
# data_inicio_atividade                0
# cnae_fiscal_principal                0
# cnae_fiscal_secundaria         1623482
# sigla_uf                             0
# id_municipio                       216
# id_municipio_rf                      0
# tipo_logradouro                  14451
# logradouro                          14
# numero                              51
# complemento                    2948089
# bairro                            2497
# cep                                216
# ...

# %%
tabela1_cnpj.nunique()
# Out:
# data                               14
# cnpj                           515874
# cnpj_basico                    504747
# cnpj_ordem                        409
# cnpj_dv                           100
# identificador_matriz_filial         2
# nome_fantasia                  344790
# situacao_cadastral                  1
# data_situacao_cadastral          6888
# motivo_situacao_cadastral           1
# nome_cidade_exterior                8
# id_pais                            12
# data_inicio_atividade           13532
# cnae_fiscal_principal               1
# cnae_fiscal_secundaria          68865
# sigla_uf                           28
# id_municipio                     5485
# id_municipio_rf                  5486
# tipo_logradouro                   291
# logradouro                     182822
# numero                          21285
# complemento                     84162
# bairro                          42421
# cep                            251284
# ddd_1                             139
# ...
