# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
PNAD = pd.read_csv('/content/drive/MyDrive/dicionario.csv')

PNAD.head(15)
# Out:
#                                 id_tabela          nome_coluna  chave  \
# 0   microdados_compatibilizados_domicilio          zona_urbana    0.0
# 1   microdados_compatibilizados_domicilio          zona_urbana    1.0
# 2   microdados_compatibilizados_domicilio  tipo_zona_domicilio    1.0
# 3   microdados_compatibilizados_domicilio  tipo_zona_domicilio    2.0
# 4   microdados_compatibilizados_domicilio  tipo_zona_domicilio    3.0
# 5   microdados_compatibilizados_domicilio    especie_domicilio    1.0
# 6   microdados_compatibilizados_domicilio    especie_domicilio    3.0
# 7   microdados_compatibilizados_domicilio    especie_domicilio    5.0
# 8   microdados_compatibilizados_domicilio       tipo_domicilio    2.0
# 9   microdados_compatibilizados_domicilio       tipo_domicilio    4.0
# 10  microdados_compatibilizados_domicilio       tipo_domicilio    6.0
# 11  microdados_compatibilizados_domicilio          tipo_parede    1.0
# ...

# %%
PNAD.info()
PNAD.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_tabela           142 non-null    object
#  1   nome_coluna         142 non-null    object
#  2   chave               141 non-null    float64
#  3   cobertura_temporal  142 non-null    object
#  4   valor               142 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 5.7+ KB
#             chave
# count  141.000000
# mean     3.141844
# std      2.740129
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      5.000000
# max     11.000000

# %%
PNAD.columns
# Out:
# Index(['id_tabela', 'nome_coluna', 'chave', 'cobertura_temporal', 'valor'], dtype='object')

# %%
PNAD.isnull().sum()
# Out:
# id_tabela             0
# nome_coluna           0
# chave                 1
# cobertura_temporal    0
# valor                 0
# dtype: int64

# %%
BRASIL = pd.read_csv('/content/drive/MyDrive/brasil.csv')

print(BRASIL)
# Out:
#      ano  populacao  populacao_economicamente_ativa
# 0   1991  146815815                             NaN
# 1   1992  149236984                             NaN
# 2   1993  151571727                             NaN
# 3   1994  153725670                             NaN
# 4   1995  155822440                             NaN
# 5   1996  157070163                             NaN
# 6   1997  159636413                             NaN
# 7   1998  161790311                             NaN
# 8   1999  163947554                             NaN
# 9   2000  169872854                             NaN
# 10  2001  172385826                             NaN
# 11  2002  174632960                             NaN
# 12  2003  176871437                             NaN
# 13  2004  181581024                             NaN
# 14  2005  184184264                             NaN
# 15  2006  186770562                             NaN
# 16  2007  184014516                             NaN
# ...

# %%
BRASIL.info()
BRASIL.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ano                             31 non-null     int64
#  1   populacao                       31 non-null     int64
#  2   populacao_economicamente_ativa  10 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 872.0 bytes
#                ano     populacao  populacao_economicamente_ativa
# count    31.000000  3.100000e+01                       10.000000
# mean   2006.000000  1.823800e+08                   164251.900000
# std       9.092121  2.105229e+07                     5686.223692
# min    1991.000000  1.468158e+08                   155330.000000
# 25%    1998.500000  1.628689e+08                   160179.000000
# 50%    2006.000000  1.841843e+08                   164531.000000
# ...

# %%
BRASIL.isnull().sum()
# Out:
# ano                                0
# populacao                          0
# populacao_economicamente_ativa    21
# dtype: int64

# %%
BRASIL.nunique()
# Out:
# ano                               31
# populacao                         31
# populacao_economicamente_ativa    10
# dtype: int64

# %%
BRASIL_ZERO = BRASIL.eq(0).sum()
print(BRASIL_ZERO)
# Out:
# ano                               0
# populacao                         0
# populacao_economicamente_ativa    0
# dtype: int64
